# %% [markdown]
# # Phase 4 — Full Evaluation Battery
#
# Runs the complete clinical evaluation battery (MMSE, verbal fluency, Boston
# Naming, clock drawing analogue) across all Braak stages and both damage phases.
#
# Produces:
# - Error type frequency histograms by stage
# - Domain-specific score trajectories
# - Thinking-mode engagement failure rates by stage

# %%
import sys
sys.path.insert(0, '..')

from disease_state import DiseaseState
from evaluation.metrics import ErrorType
print('Stub — implement after Phase 3 validation.')
