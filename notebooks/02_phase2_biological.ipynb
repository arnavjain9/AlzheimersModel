# %% [markdown]
# # Phase 2 — Biological Realism Experiments
#
# Tests whether biologically-ordered damage (entorhinal → hippocampal → temporal
# → prefrontal) produces qualitatively different symptom profiles than control
# conditions.
#
# Control conditions:
# - Random noise (non-patterned)
# - Uniform damage (all layers equal)
# - Reversed staging (prefrontal first)
#
# Expected result: AD-patterned staging produces earlier and more pronounced
# semantic paraphasias and episodic failure than controls at the same total
# damage budget.

# %%
import sys
sys.path.insert(0, '..')

from disease_state import DiseaseState, BraakStage, DamagePhase, DamageIntensity
print('Stub — implement after Phase 1 validation.')
