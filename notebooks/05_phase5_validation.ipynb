# %% [markdown]
# # Phase 5 — Clinical Comparison and Ablations
#
# Compares simulated decline curves against published AD patient cohort data.
#
# Ablation studies:
# - Remove functional clustering → random neuron death control
# - Remove compensation modeling → abrupt cliff instead of gradual decline
# - Remove Braak ordering → uniform damage control
# - Remove Phase 1/2 distinction → single-phase control
#
# Validates that each design choice contributes to biological realism.

# %%
import sys
sys.path.insert(0, '..')

from disease_state import DiseaseState
from evaluation.longitudinal import compare_to_clinical_profile
print('Stub — implement after Phase 4 validation.')
