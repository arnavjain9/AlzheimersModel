# %% [markdown]
# # Phase 3 — Temporal Dynamics
#
# Runs the full Braak staging sequence from I-II → VI across multiple epochs,
# tracking:
# - Compensation reserve depletion and tipping-point detection
# - Phase 1 → Phase 2 transition effects
# - Spreading dynamics from entorhinal seed layers
# - Per-region damage curves vs. published Braak progression timelines

# %%
import sys
sys.path.insert(0, '..')

from disease_state import DiseaseState, BraakStage, DamagePhase, DamageIntensity
print('Stub — implement after Phase 2 validation.')
